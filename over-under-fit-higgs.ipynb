# %%
import tensorflow as tf

from tensorflow.keras import layers
from tensorflow.keras import regularizers

print(tf.__version__)
# Out:
# 2.2.0

# %%
import tensorflow_docs as tfdocs
import tensorflow_docs.modeling
import tensorflow_docs.plots

# %%
from IPython import display
from matplotlib import pyplot as plt

import numpy as np

import pathlib
import shutil
import tempfile

# %%
logdir = pathlib.Path(tempfile.mkdtemp())/"tensorboard_logs"
shutil.rmtree(logdir,ignore_errors=True)

# %%
gz = tf.keras.utils.get_file('HIGGS.csv.gz', 'http://mlphysics.ics.uci.edu/data/higgs/HIGGS.csv.gz')
# Out:
# Downloading data from http://mlphysics.ics.uci.edu/data/higgs/HIGGS.csv.gz
# 2816409600/2816407858 [==============================] - 1197s 0us/step

# %%
FEATURES = 28
ds = tf.data.experimental.CsvDataset(gz,[float(),]*(FEATURES+1), compression_type="GZIP")

# %%
def pack_row(*row):
  label = row[0]
  features = tf.stack(row[1:],1)
  return features, label

# %%
packed_ds = ds.batch(10000).map(pack_row).unbatch()

# %%
for features,label in packed_ds.batch(1000).take(1):
  print(features[0])
  plt.hist(features.numpy().flatten(), bins = 101)
# Out:
# tf.Tensor(
# [ 0.8692932  -0.6350818   0.22569026  0.32747006 -0.6899932   0.75420225
#  -0.24857314 -1.0920639   0.          1.3749921  -0.6536742   0.9303491
#   1.1074361   1.1389043  -1.5781983  -1.0469854   0.          0.65792954
#  -0.01045457 -0.04576717  3.1019614   1.35376     0.9795631   0.97807616
#   0.92000484  0.72165745  0.98875093  0.87667835], shape=(28,), dtype=float32)

# %%
N_VALIDATION = int(1e3)
N_TRAIN = int(1e4)
BUFFER_SIZE = int(1e4)
BATCH_SIZE = 500
STEPS_PER_EPOCH = N_TRAIN//BATCH_SIZE

# %%
validate_ds = packed_ds.take(N_VALIDATION).cache()
train_ds = packed_ds.skip(N_VALIDATION).take(N_TRAIN).cache()

# %%
train_ds
# Out:
# <CacheDataset shapes: ((28,), ()), types: (tf.float32, tf.float32)>

# %%
validate_ds = validate_ds.batch(BATCH_SIZE)
train_ds = train_ds.shuffle(BUFFER_SIZE).repeat().batch(BATCH_SIZE)

# %%
#Many models train better if you gradually reduce the learning rate during training. Use optimizers.schedules to reduce the learning rate over time:
lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
0.001,
decay_steps = STEPS_PER_EPOCH*1000,
decay_rate = 1,
staircase = False)

def get_optimizer():
    return tf.keras.optimizers.Adam(lr_schedule)

# %%
step = np.linspace(0,100000)
lr = lr_schedule(step)
plt.figure(figsize = (8,6))
plt.plot(step/STEPS_PER_EPOCH,lr)
plt.ylim([0,max(plt.ylim())])
plt.xlabel('Epoch')
_ = plt.ylabel('Learning Rate')

# %%
def get_callbacks(name):
  return [
    tfdocs.modeling.EpochDots(),
    tf.keras.callbacks.EarlyStopping(monitor='val_binary_crossentropy', patience=200),
    tf.keras.callbacks.TensorBoard(logdir/name),
  ]

# %%
def compile_and_fit(model, name, optimizer=None, max_epochs=10000):
  if optimizer is None:
    optimizer = get_optimizer()
  model.compile(optimizer=optimizer,
                loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                metrics=[
                  tf.keras.losses.BinaryCrossentropy(
                      from_logits=True, name='binary_crossentropy'),
                  'accuracy'])

  model.summary()

  history = model.fit(
    train_ds,
    steps_per_epoch = STEPS_PER_EPOCH,
    epochs=max_epochs,
    validation_data=validate_ds,
    callbacks=get_callbacks(name),
    verbose=0)
  return history

# %%
tiny_model = tf.keras.Sequential([
    layers.Dense(16, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(1)
])

# %%
size_histories = {}

# %%
size_histories['Tiny'] = compile_and_fit(tiny_model, 'sizes/Tiny')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                464
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 481
# Trainable params: 481
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.692252). Check your callbacks.
#
# Epoch: 0, accuracy:0.4814,  binary_crossentropy:0.8242,  loss:0.8242,  val_accuracy:0.5010,  val_binary_crossentropy:0.7440,  val_loss:0.7440,
# ....................................................................................................
# Epoch: 100, accuracy:0.5846,  binary_crossentropy:0.6316,  loss:0.6316,  val_accuracy:0.5810,  val_binary_crossentropy:0.6329,  val_loss:0.6329,
# ....................................................................................................
# Epoch: 200, accuracy:0.6135,  binary_crossentropy:0.6184,  loss:0.6184,  val_accuracy:0.5930,  val_binary_crossentropy:0.6193,  val_loss:0.6193,
# ....................................................................................................
# Epoch: 300, accuracy:0.6387,  binary_crossentropy:0.6065,  loss:0.6065,  val_accuracy:0.6070,  val_binary_crossentropy:0.6083,  val_loss:0.6083,
# ....................................................................................................
# Epoch: 400, accuracy:0.6456,  binary_crossentropy:0.5992,  loss:0.5992,  val_accuracy:0.6370,  val_binary_crossentropy:0.6011,  val_loss:0.6011,
# ....................................................................................................
# Epoch: 500, accuracy:0.6546,  binary_crossentropy:0.5942,  loss:0.5942,  val_accuracy:0.6220,  val_binary_crossentropy:0.5999,  val_loss:0.5999,
# ....................................................................................................
# Epoch: 600, accuracy:0.6555,  binary_crossentropy:0.5905,  loss:0.5905,  val_accuracy:0.6480,  val_binary_crossentropy:0.5968,  val_loss:0.5968,
# ....................................................................................................
# Epoch: 700, accuracy:0.6610,  binary_crossentropy:0.5873,  loss:0.5873,  val_accuracy:0.6550,  val_binary_crossentropy:0.5950,  val_loss:0.5950,
# ....................................................................................................
# Epoch: 800, accuracy:0.6662,  binary_crossentropy:0.5845,  loss:0.5845,  val_accuracy:0.6230,  val_binary_crossentropy:0.5968,  val_loss:0.5968,
# ....................................................................................................
# Epoch: 900, accuracy:0.6707,  binary_crossentropy:0.5818,  loss:0.5818,  val_accuracy:0.6340,  val_binary_crossentropy:0.5952,  val_loss:0.5952,
# ....................................................................................................
# Epoch: 1000, accuracy:0.6659,  binary_crossentropy:0.5807,  loss:0.5807,  val_accuracy:0.6580,  val_binary_crossentropy:0.5907,  val_loss:0.5907,
# ....................................................................................................
# Epoch: 1100, accuracy:0.6732,  binary_crossentropy:0.5781,  loss:0.5781,  val_accuracy:0.6420,  val_binary_crossentropy:0.5919,  val_loss:0.5919,
# ....................................................................................................
# Epoch: 1200, accuracy:0.6686,  binary_crossentropy:0.5773,  loss:0.5773,  val_accuracy:0.6390,  val_binary_crossentropy:0.5910,  val_loss:0.5910,
# ....................................................................................................
# Epoch: 1300, accuracy:0.6737,  binary_crossentropy:0.5751,  loss:0.5751,  val_accuracy:0.6540,  val_binary_crossentropy:0.5892,  val_loss:0.5892,
# ....................................................................................................
# Epoch: 1400, accuracy:0.6786,  binary_crossentropy:0.5739,  loss:0.5739,  val_accuracy:0.6390,  val_binary_crossentropy:0.5916,  val_loss:0.5916,
# ....................................................................................................
# Epoch: 1500, accuracy:0.6769,  binary_crossentropy:0.5734,  loss:0.5734,  val_accuracy:0.6430,  val_binary_crossentropy:0.5916,  val_loss:0.5916,
# ....................................................................................................
# Epoch: 1600, accuracy:0.6793,  binary_crossentropy:0.5721,  loss:0.5721,  val_accuracy:0.6420,  val_binary_crossentropy:0.5912,  val_loss:0.5912,
# ....................................................................................................
# Epoch: 1700, accuracy:0.6784,  binary_crossentropy:0.5714,  loss:0.5714,  val_accuracy:0.6620,  val_binary_crossentropy:0.5872,  val_loss:0.5872,
# ....................................................................................................
# Epoch: 1800, accuracy:0.6803,  binary_crossentropy:0.5705,  loss:0.5705,  val_accuracy:0.6640,  val_binary_crossentropy:0.5877,  val_loss:0.5877,
# ....................................................................................................
# Epoch: 1900, accuracy:0.6819,  binary_crossentropy:0.5699,  loss:0.5699,  val_accuracy:0.6540,  val_binary_crossentropy:0.5881,  val_loss:0.5881,
# ....................................................................................................
# Epoch: 2000, accuracy:0.6821,  binary_crossentropy:0.5695,  loss:0.5695,  val_accuracy:0.6430,  val_binary_crossentropy:0.5904,  val_loss:0.5904,
# ....................................................................................................
# Epoch: 2100, accuracy:0.6798,  binary_crossentropy:0.5683,  loss:0.5683,  val_accuracy:0.6630,  val_binary_crossentropy:0.5865,  val_loss:0.5865,
# ....................................................................................................
# Epoch: 2200, accuracy:0.6827,  binary_crossentropy:0.5677,  loss:0.5677,  val_accuracy:0.6500,  val_binary_crossentropy:0.5890,  val_loss:0.5890,
# ....................................................................................................
# Epoch: 2300, accuracy:0.6831,  binary_crossentropy:0.5668,  loss:0.5668,  val_accuracy:0.6520,  val_binary_crossentropy:0.5876,  val_loss:0.5876,
# ....................................................................................................
# Epoch: 2400, accuracy:0.6850,  binary_crossentropy:0.5665,  loss:0.5665,  val_accuracy:0.6550,  val_binary_crossentropy:0.5869,  val_loss:0.5869,
# ....................................................................................................
# Epoch: 2500, accuracy:0.6840,  binary_crossentropy:0.5660,  loss:0.5660,  val_accuracy:0.6580,  val_binary_crossentropy:0.5852,  val_loss:0.5852,
# ....................................................................................................
# Epoch: 2600, accuracy:0.6819,  binary_crossentropy:0.5654,  loss:0.5654,  val_accuracy:0.6620,  val_binary_crossentropy:0.5846,  val_loss:0.5846,
# ....................................................................................................
# Epoch: 2700, accuracy:0.6840,  binary_crossentropy:0.5649,  loss:0.5649,  val_accuracy:0.6570,  val_binary_crossentropy:0.5847,  val_loss:0.5847,
# ....................................................................................................
# Epoch: 2800, accuracy:0.6881,  binary_crossentropy:0.5643,  loss:0.5643,  val_accuracy:0.6540,  val_binary_crossentropy:0.5845,  val_loss:0.5845,
# ....................................................................................................
# Epoch: 2900, accuracy:0.6858,  binary_crossentropy:0.5642,  loss:0.5642,  val_accuracy:0.6600,  val_binary_crossentropy:0.5831,  val_loss:0.5831,
# ....................................................................................................
# Epoch: 3000, accuracy:0.6866,  binary_crossentropy:0.5635,  loss:0.5635,  val_accuracy:0.6570,  val_binary_crossentropy:0.5836,  val_loss:0.5836,
# ....................................................................................................
# Epoch: 3100, accuracy:0.6875,  binary_crossentropy:0.5630,  loss:0.5630,  val_accuracy:0.6580,  val_binary_crossentropy:0.5838,  val_loss:0.5838,
# ....................................................................................................
# Epoch: 3200, accuracy:0.6844,  binary_crossentropy:0.5626,  loss:0.5626,  val_accuracy:0.6600,  val_binary_crossentropy:0.5818,  val_loss:0.5818,
# ....................................................................................................
# Epoch: 3300, accuracy:0.6843,  binary_crossentropy:0.5623,  loss:0.5623,  val_accuracy:0.6620,  val_binary_crossentropy:0.5816,  val_loss:0.5816,
# ....................................................................................................
# Epoch: 3400, accuracy:0.6824,  binary_crossentropy:0.5621,  loss:0.5621,  val_accuracy:0.6650,  val_binary_crossentropy:0.5808,  val_loss:0.5808,
# ....................................................................................................
# Epoch: 3500, accuracy:0.6859,  binary_crossentropy:0.5616,  loss:0.5616,  val_accuracy:0.6590,  val_binary_crossentropy:0.5809,  val_loss:0.5809,
# ....................................................................................................
# Epoch: 3600, accuracy:0.6858,  binary_crossentropy:0.5614,  loss:0.5614,  val_accuracy:0.6600,  val_binary_crossentropy:0.5811,  val_loss:0.5811,
# ....................................................................................................
# Epoch: 3700, accuracy:0.6885,  binary_crossentropy:0.5610,  loss:0.5610,  val_accuracy:0.6630,  val_binary_crossentropy:0.5801,  val_loss:0.5801,
# ....................................................................................................
# Epoch: 3800, accuracy:0.6902,  binary_crossentropy:0.5607,  loss:0.5607,  val_accuracy:0.6570,  val_binary_crossentropy:0.5811,  val_loss:0.5811,
# ....................................................................................................
# Epoch: 3900, accuracy:0.6844,  binary_crossentropy:0.5607,  loss:0.5607,  val_accuracy:0.6660,  val_binary_crossentropy:0.5790,  val_loss:0.5790,
# ....................................................................................................
# Epoch: 4000, accuracy:0.6878,  binary_crossentropy:0.5604,  loss:0.5604,  val_accuracy:0.6660,  val_binary_crossentropy:0.5789,  val_loss:0.5789,
# ....................................................................................................
# Epoch: 4100, accuracy:0.6894,  binary_crossentropy:0.5601,  loss:0.5601,  val_accuracy:0.6630,  val_binary_crossentropy:0.5796,  val_loss:0.5796,
# ....................................................................................................
# Epoch: 4200, accuracy:0.6879,  binary_crossentropy:0.5598,  loss:0.5598,  val_accuracy:0.6640,  val_binary_crossentropy:0.5789,  val_loss:0.5789,
# ....................................................................................................
# Epoch: 4300, accuracy:0.6879,  binary_crossentropy:0.5596,  loss:0.5596,  val_accuracy:0.6670,  val_binary_crossentropy:0.5786,  val_loss:0.5786,
# ....................................................................................................
# Epoch: 4400, accuracy:0.6909,  binary_crossentropy:0.5595,  loss:0.5595,  val_accuracy:0.6640,  val_binary_crossentropy:0.5786,  val_loss:0.5786,
# ....................................................................................................
# Epoch: 4500, accuracy:0.6922,  binary_crossentropy:0.5592,  loss:0.5592,  val_accuracy:0.6710,  val_binary_crossentropy:0.5779,  val_loss:0.5779,
# ....................................................................................................
# Epoch: 4600, accuracy:0.6863,  binary_crossentropy:0.5593,  loss:0.5593,  val_accuracy:0.6730,  val_binary_crossentropy:0.5774,  val_loss:0.5774,
# ....................................................................................................
# Epoch: 4700, accuracy:0.6943,  binary_crossentropy:0.5587,  loss:0.5587,  val_accuracy:0.6680,  val_binary_crossentropy:0.5781,  val_loss:0.5781,
# ....................................................................................................
# Epoch: 4800, accuracy:0.6934,  binary_crossentropy:0.5584,  loss:0.5584,  val_accuracy:0.6670,  val_binary_crossentropy:0.5779,  val_loss:0.5779,
# ....................................................................................................
# Epoch: 4900, accuracy:0.6898,  binary_crossentropy:0.5582,  loss:0.5582,  val_accuracy:0.6700,  val_binary_crossentropy:0.5771,  val_loss:0.5771,
# ....................................................................................................
# Epoch: 5000, accuracy:0.6880,  binary_crossentropy:0.5583,  loss:0.5583,  val_accuracy:0.6690,  val_binary_crossentropy:0.5777,  val_loss:0.5777,
# ....................................................................................................
# Epoch: 5100, accuracy:0.6909,  binary_crossentropy:0.5578,  loss:0.5578,  val_accuracy:0.6730,  val_binary_crossentropy:0.5768,  val_loss:0.5768,
# ....................................................................................................
# Epoch: 5200, accuracy:0.6929,  binary_crossentropy:0.5577,  loss:0.5577,  val_accuracy:0.6760,  val_binary_crossentropy:0.5766,  val_loss:0.5766,
# ....................................................................................................
# Epoch: 5300, accuracy:0.6894,  binary_crossentropy:0.5576,  loss:0.5576,  val_accuracy:0.6770,  val_binary_crossentropy:0.5758,  val_loss:0.5758,
# .................

# %%
plotter = tfdocs.plots.HistoryPlotter(metric = 'binary_crossentropy',smoothing_std = 10)
plotter.plot(size_histories)
plt.ylim([0.5,0.7])
# Out:
# (0.5, 0.7)

# %%
small_model = tf.keras.Sequential([
    # `input_shape` is only required here so that `.summary` works.
    layers.Dense(16, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(16, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['Small'] = compile_and_fit(small_model, 'sizes/Small')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 16)                464
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 753
# Trainable params: 753
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.548953). Check your callbacks.
#
# Epoch: 0, accuracy:0.4985,  binary_crossentropy:0.7115,  loss:0.7115,  val_accuracy:0.5020,  val_binary_crossentropy:0.6929,  val_loss:0.6929,
# ....................................................................................................
# Epoch: 100, accuracy:0.6307,  binary_crossentropy:0.6110,  loss:0.6110,  val_accuracy:0.6090,  val_binary_crossentropy:0.6127,  val_loss:0.6127,
# ....................................................................................................
# Epoch: 200, accuracy:0.6692,  binary_crossentropy:0.5869,  loss:0.5869,  val_accuracy:0.6490,  val_binary_crossentropy:0.5876,  val_loss:0.5876,
# ....................................................................................................
# Epoch: 300, accuracy:0.6746,  binary_crossentropy:0.5756,  loss:0.5756,  val_accuracy:0.6650,  val_binary_crossentropy:0.5841,  val_loss:0.5841,
# ....................................................................................................
# Epoch: 400, accuracy:0.6857,  binary_crossentropy:0.5681,  loss:0.5681,  val_accuracy:0.6670,  val_binary_crossentropy:0.5851,  val_loss:0.5851,
# ....................................................................................................
# Epoch: 500, accuracy:0.6876,  binary_crossentropy:0.5625,  loss:0.5625,  val_accuracy:0.6660,  val_binary_crossentropy:0.5875,  val_loss:0.5875,
# ........................................................................................

# %%
medium_model = tf.keras.Sequential([
    layers.Dense(64, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(64, activation='elu'),
    layers.Dense(64, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['Medium']  = compile_and_fit(medium_model, "sizes/Medium")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 64)                1856
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 10,241
# Trainable params: 10,241
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.792163). Check your callbacks.
#
# Epoch: 0, accuracy:0.4903,  binary_crossentropy:0.6894,  loss:0.6894,  val_accuracy:0.5410,  val_binary_crossentropy:0.6659,  val_loss:0.6659,
# ....................................................................................................
# Epoch: 100, accuracy:0.7171,  binary_crossentropy:0.5291,  loss:0.5291,  val_accuracy:0.6760,  val_binary_crossentropy:0.5981,  val_loss:0.5981,
# ....................................................................................................
# Epoch: 200, accuracy:0.7912,  binary_crossentropy:0.4233,  loss:0.4233,  val_accuracy:0.6700,  val_binary_crossentropy:0.6841,  val_loss:0.6841,
# .......................................................................

# %%
large_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(512, activation='elu'),
    layers.Dense(512, activation='elu'),
    layers.Dense(512, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['large'] = compile_and_fit(large_model, "sizes/large")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 512)               14848
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_11 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.577974). Check your callbacks.
#
# Epoch: 0, accuracy:0.5110,  binary_crossentropy:0.7627,  loss:0.7627,  val_accuracy:0.5080,  val_binary_crossentropy:0.6844,  val_loss:0.6844,
# ....................................................................................................
# Epoch: 100, accuracy:1.0000,  binary_crossentropy:0.0018,  loss:0.0018,  val_accuracy:0.6500,  val_binary_crossentropy:1.8160,  val_loss:1.8160,
# ....................................................................................................
# Epoch: 200, accuracy:1.0000,  binary_crossentropy:0.0001,  loss:0.0001,  val_accuracy:0.6490,  val_binary_crossentropy:2.4410,  val_loss:2.4410,
# ...........................

# %%
plotter.plot(size_histories)
a = plt.xscale('log')
plt.xlim([5, max(plt.xlim())])
plt.ylim([0.4, 0.7])
plt.xlabel("Epochs [Log Scale]")
# Out:
# Text(0.5, 0, 'Epochs [Log Scale]')

# %%
# Load the TensorBoard notebook extension
# %reload_ext tensorboard

# Open an embedded TensorBoard viewer
# %tensorboard --logdir {logdir}/sizes
# Out:
# Reusing TensorBoard on port 6006 (pid 2316), started 0:00:19 ago. (Use '!kill 2316' to kill it.)
#       <iframe id="tensorboard-frame-90e178968b3f5384" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-90e178968b3f5384");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>

# %%
display.IFrame(
    src="https://tensorboard.dev/experiment/vW7jmmF9TmKmy3rbheMQpw/#scalars&_smoothingWeight=0.97",
    width="100%", height="800px")
# Out:
#         <iframe
#             width="100%"
#             height="800px"
#             src="https://tensorboard.dev/experiment/vW7jmmF9TmKmy3rbheMQpw/#scalars&_smoothingWeight=0.97"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
shutil.rmtree(logdir/'regularizers/Tiny', ignore_errors=True)
shutil.copytree(logdir/'sizes/Tiny', logdir/'regularizers/Tiny')
# Out:
# WindowsPath('C:/Users/preetham/AppData/Local/Temp/tmpak_mhxyb/tensorboard_logs/regularizers/Tiny')

# %%
regularizer_histories = {}
regularizer_histories['Tiny'] = size_histories['Tiny']

# %%
l2_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001),
                 input_shape=(FEATURES,)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(512, activation='elu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(1)
])

regularizer_histories['l2'] = compile_and_fit(l2_model, "regularizers/l2")
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_14 (Dense)             (None, 512)               14848
# _________________________________________________________________
# dense_15 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_16 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_17 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (2.370491). Check your callbacks.
#
# Epoch: 0, accuracy:0.5146,  binary_crossentropy:0.7772,  loss:2.2879,  val_accuracy:0.4960,  val_binary_crossentropy:0.6958,  val_loss:2.1155,
# ....................................................................................................
# Epoch: 100, accuracy:0.6608,  binary_crossentropy:0.5923,  loss:0.6167,  val_accuracy:0.6370,  val_binary_crossentropy:0.5890,  val_loss:0.6133,
# ....................................................................................................
# Epoch: 200, accuracy:0.6761,  binary_crossentropy:0.5761,  loss:0.6003,  val_accuracy:0.6900,  val_binary_crossentropy:0.5742,  val_loss:0.5981,
# ....................................................................................................
# Epoch: 300, accuracy:0.6853,  binary_crossentropy:0.5710,  loss:0.5963,  val_accuracy:0.6370,  val_binary_crossentropy:0.5959,  val_loss:0.6211,
# ....................................................................................................
# Epoch: 400, accuracy:0.6932,  binary_crossentropy:0.5608,  loss:0.5871,  val_accuracy:0.6540,  val_binary_crossentropy:0.5807,  val_loss:0.6070,
# ....................................................................................................
# Epoch: 500, accuracy:0.6945,  binary_crossentropy:0.5621,  loss:0.5917,  val_accuracy:0.6850,  val_binary_crossentropy:0.5848,  val_loss:0.6148,
# ....................................................................................................
# Epoch: 600, accuracy:0.7021,  binary_crossentropy:0.5468,  loss:0.5751,  val_accuracy:0.6860,  val_binary_crossentropy:0.5789,  val_loss:0.6073,
# ..........

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
dropout_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu', input_shape=(FEATURES,)),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(1)
])

regularizer_histories['dropout'] = compile_and_fit(dropout_model, "regularizers/dropout")
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 512)               14848
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.703505). Check your callbacks.
#
# Epoch: 0, accuracy:0.5063,  binary_crossentropy:0.7923,  loss:0.7923,  val_accuracy:0.4640,  val_binary_crossentropy:0.6870,  val_loss:0.6870,
# ....................................................................................................
# Epoch: 100, accuracy:0.6556,  binary_crossentropy:0.5955,  loss:0.5955,  val_accuracy:0.6720,  val_binary_crossentropy:0.5854,  val_loss:0.5854,
# ....................................................................................................
# Epoch: 200, accuracy:0.6852,  binary_crossentropy:0.5606,  loss:0.5606,  val_accuracy:0.6900,  val_binary_crossentropy:0.5830,  val_loss:0.5830,
# ....................................................................................................
# Epoch: 300, accuracy:0.7192,  binary_crossentropy:0.5137,  loss:0.5137,  val_accuracy:0.6850,  val_binary_crossentropy:0.5992,  val_loss:0.5992,
# ...............................................

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
combined_model = tf.keras.Sequential([
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu', input_shape=(FEATURES,)),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(1)
])

regularizer_histories['combined'] = compile_and_fit(combined_model, "regularizers/combined")
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             (None, 512)               14848
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.725177). Check your callbacks.
#
# Epoch: 0, accuracy:0.5036,  binary_crossentropy:0.7875,  loss:0.9456,  val_accuracy:0.5310,  val_binary_crossentropy:0.6701,  val_loss:0.8275,
# ....................................................................................................
# Epoch: 100, accuracy:0.6554,  binary_crossentropy:0.6035,  loss:0.6326,  val_accuracy:0.6540,  val_binary_crossentropy:0.5834,  val_loss:0.6124,
# ....................................................................................................
# Epoch: 200, accuracy:0.6667,  binary_crossentropy:0.5887,  loss:0.6144,  val_accuracy:0.6710,  val_binary_crossentropy:0.5811,  val_loss:0.6068,
# ....................................................................................................
# Epoch: 300, accuracy:0.6707,  binary_crossentropy:0.5807,  loss:0.6092,  val_accuracy:0.6750,  val_binary_crossentropy:0.5649,  val_loss:0.5934,
# ....................................................................................................
# Epoch: 400, accuracy:0.6748,  binary_crossentropy:0.5735,  loss:0.6043,  val_accuracy:0.6940,  val_binary_crossentropy:0.5559,  val_loss:0.5867,
# ....................................................................................................
# Epoch: 500, accuracy:0.6795,  binary_crossentropy:0.5729,  loss:0.6054,  val_accuracy:0.6710,  val_binary_crossentropy:0.5580,  val_loss:0.5906,
# ....................................................................................................
# Epoch: 600, accuracy:0.6815,  binary_crossentropy:0.5679,  loss:0.6026,  val_accuracy:0.6850,  val_binary_crossentropy:0.5552,  val_loss:0.5900,
# ....................................................................................................
# Epoch: 700, accuracy:0.6908,  binary_crossentropy:0.5598,  loss:0.5965,  val_accuracy:0.6960,  val_binary_crossentropy:0.5511,  val_loss:0.5879,
# ....................................................................................................
# Epoch: 800, accuracy:0.6859,  binary_crossentropy:0.5592,  loss:0.5976,  val_accuracy:0.6780,  val_binary_crossentropy:0.5536,  val_loss:0.5920,
# .................................................................................

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
# %tensorboard --logdir {logdir}/regularizers
# Out:
# Reusing TensorBoard on port 6006 (pid 11320), started 0:06:06 ago. (Use '!kill 11320' to kill it.)
#       <iframe id="tensorboard-frame-991a84a7b6d1a299" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-991a84a7b6d1a299");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>
